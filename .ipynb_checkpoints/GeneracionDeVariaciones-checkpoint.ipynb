# %%
import re
import requests
import json

# %%
def eliminar_guiones(marca):
    return marca.replace("-", "").replace(" ", "")

# %%
def variaciones_separadores(marca):
    separadores = ["_", "-", ".", ""]
    variaciones = []
    for sep in separadores:
        variacion = marca.replace(" ", sep)
        variaciones.append(variacion)
    return variaciones

# %%
def variaciones_sin_separadores(marca):
    marca_sin_separadores = marca.replace("-", "").replace(" ", "")
    
    variaciones = [
        marca_sin_separadores.lower(),
        marca_sin_separadores.upper(), 
        marca_sin_separadores.title(), 
        marca_sin_separadores[0].upper() + marca_sin_separadores[1:].lower()
    ]
    
    return list(variaciones)

# %%
def variaciones_mayusculas(marca):
    return [marca.lower(), marca.upper(), marca.title(), marca[0].upper()+marca[1:].lower()]

# %%
def variaciones_geograficas(marca):
    geos = ["MX", "US"]
    variaciones = []
    for geo in geos:
        variaciones.append(f"{marca}{geo}")
        variaciones.append(f"{marca}_{geo}")
        variaciones.append(f"{marca}-{geo}")
    return variaciones

# %%
def variaciones_numericas(marca):
    numeros = [str(i) for i in range(1, 6)] + ["2020", "2021", "2022", "2023", "2024", "2025"]
    variaciones = []
    for num in numeros:
        variaciones.append(f"{marca}{num}")
        variaciones.append(f"{marca}_{num}")
        variaciones.append(f"{marca}-{num}")
    return variaciones

# %%
def variaciones_palabras_adicionales(marca):
    palabras = ["official", "fan", "page", "oficial", "america", "mexico"]
    variaciones = []
    for palabra in palabras:
        variaciones.append(f"{marca}{palabra}")
        variaciones.append(f"{marca}_{palabra}")
        variaciones.append(f"{marca}-{palabra}")
        variaciones.append(f"{marca} {palabra}")
    return variaciones

# %%
def variaciones_errores_tipograficos(marca):
    reemplazos = {
        "a": ["@", "4"],
        "e": ["3"],
        "i": ["1", "!"],
        "o": ["0"],
        "s": ["5", "$"]
    }
    variaciones = []
    for i, char in enumerate(marca):
        if char.lower() in reemplazos:
            for reemplazo in reemplazos[char.lower()]:
                nueva_variacion = marca[:i] + reemplazo + marca[i+1:]
                variaciones.append(nueva_variacion)
    return variaciones

# %%
def generar_todas_variaciones(marca):

    marca_sin_caracteres = eliminar_guiones(marca)
    marcas = [marca, marca_sin_caracteres]
    variaciones = []
    for m in marcas:
        
        variaciones.extend(variaciones_separadores(m))
        variaciones.extend(variaciones_mayusculas(m))
        variaciones.extend(variaciones_geograficas(m))
        variaciones.extend(variaciones_numericas(m))
        variaciones.extend(variaciones_palabras_adicionales(m))
        variaciones.extend(variaciones_errores_tipograficos(m))
        variaciones.extend(variaciones_sin_separadores(m))
    
    variaciones = list(set(variaciones))
    return variaciones

# %%
def generar_urls_con_variaciones(variaciones, plataformas):
    patrones_url = {
        "facebook": "https://www.facebook.com/{username}",
        "x": "https://x.com/{username}",
        "instagram": "https://www.instagram.com/{username}",
        "tiktok": "https://www.tiktok.com/{username}"
    }
    
    urls_por_plataforma = {plataforma: [] for plataforma in plataformas}
    
    for plataforma in plataformas:
        if plataforma in patrones_url:
            for variacion in variaciones:
                url = patrones_url[plataforma].format(username=variacion)
                urls_por_plataforma[plataforma].append(url)
    
    return urls_por_plataforma

# %%
def buscar_en_google(consulta, num_resultados=10):
    base_url = "https://www.google.com/search"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    params = {"q": consulta, "num": num_resultados}

    try:
        response = requests.get(base_url, headers=headers, params=params)
        response.raise_for_status()
        html = response.text

        enlaces = re.findall(r'/url\?q=(https?://[^&]*)', html)
        enlaces_limpios = [re.sub(r'%.*$', '', enlace) for enlace in enlaces]

        return enlaces_limpios[:num_resultados]
    except Exception as e:
        print(f"Error al realizar la búsqueda en Google: {e}")
        return []

# %%
def resultados_json():
    variaciones = generar_todas_variaciones(nombre_marca)
    archivo_resultados = "resultados_google.json"
    try:
        with open(archivo_resultados, "r") as archivo:
            resultados_totales = json.load(archivo)
            print("Archivo de resultados cargado correctamente.")
    except FileNotFoundError:
        print("Archivo de resultados no encontrado. Se generarán nuevos resultados.")
        resultados_totales = {}

    for variacion in variaciones:
        if variacion not in resultados_totales:
            print(f"Realizando búsqueda para: {variacion}")
            resultados = buscar_en_google(variacion, num_resultados=5)
            resultados_totales[variacion] = resultados

    with open(archivo_resultados, "w") as archivo:
        json.dump(resultados_totales, archivo, indent=4)

    print("Resultados de búsqueda guardados en 'resultados_google.json'")

# %%
if __name__== "__main__":
    nombre_marca = "coca-cola"
    plataformas = ["facebook", "x", "instagram"]
    
    variaciones = generar_todas_variaciones(nombre_marca)
    
    print(f"Variaciones generadas para '{nombre_marca}':")
    for i, variacion in enumerate(variaciones, 1):
        print(f"{i}. {variacion}")
    
    print(f"\nPlataformas a analizar: {', '.join(plataformas)}")

    urls_generadas = generar_urls_con_variaciones(variaciones, plataformas)
    
    for plataforma, urls in urls_generadas.items():
        print(f"\nURLs generadas para {plataforma}:")
        for i, url in enumerate(urls, 1):
            print(f"{i}. {url}")

    resultados_json()
# Out:
# Variaciones generadas para 'coca-cola':
# 1. coca-cola_2025
# 2. coca-cola-2021
# 3. cocacola-MX
# 4. coca-cola_2023
# 5. coca-cola page
# 6. Coca-cola
# 7. cocacola2024
# 8. coca-cola2024
# 9. cocacola_fan
# 10. coca-cola-page
# 11. cocacola-official
# 12. cocacola mexico
# 13. coca-cola-4
# 14. coca-cola_1
# 15. coca-colaamerica
# 16. coca-cola_america
# 17. cocacola-2024
# 18. cocacola official
# 19. cocacola
# 20. cocacola_MX
# 21. coca-colafan
# 22. coca-cola2020
# 23. coca-cola1
# 24. coc4-cola
# 25. cocacola-2020
# 26. cocacolaamerica
# 27. cocacola-mexico
# 28. cocacola-1
# 29. cocacolaUS
# 30. coca-cola-oficial
# 31. cocacola-2025
# 32. coca-cola fan
# 33. cocacol@
# 34. coca-cola-US
# 35. coca-cola2025
# 36. cocacola-2022
# 37. coca-c0la
# 38. coca-cola-2020
# 39. coca-cola-mexico
# 40. coca-cola_MX
# 41. cocacola_US
# 42. coca-cola_4
# 43. cocacola_2
# 44. coca-cola oficial
# 45. coca-cola_2020
# 46. coca-cola
# 47. cocacola-2021
# 48. cocacola2022
# 49. coca-cola-official
# 50. coca-colaMX
# 51. coca-colamexico
# 52. cocacola-2
# 53. coca-cola_2021
# 54. coc@cola
# 55. cocacola5
# 56. cocacola4
# 57. coca-cola-2025
# 58. coca-cola_fan
# 59. cocacola-2023
# 60. coca-cola-1
# 61. cocacola_2024
# 62. cocacola_2023
# 63. cocacola_oficial
# 64. coca-colapage
# 65. cocacola2025
# 66. coca-cola_5
# 67. coca-cola2023
# 68. cocacola_2020
# 69. cocacola-fan
# 70. coca-cola-MX
# 71. coca-cola-2022
# 72. coca-cola-fan
# 73. cocacolafan
# 74. coca-cola_2
# 75. coca-col4
# 76. cocacola fan
# 77. cocacola-3
# 78. cocacola-5
# 79. COCA-COLA
# 80. coca-cola_official
# 81. cocacola-america
# 82. cocacola3
# 83. coca-cola mexico
# 84. coca-cola official
# 85. cocacolamexico
# 86. cocacola oficial
# 87. cocacolaoficial
# 88. coca-cola_page
# 89. coca-cola america
# 90. coca-cola2021
# 91. coca-cola2
# 92. coca-cola_3
# 93. cocac0la
# 94. coca-cola-3
# 95. Coca-Cola
# 96. coca-cola-5
# 97. cocacola_3
# 98. c0cacola
# 99. cocacolaofficial
# 100. coca-cola3
# 101. coca-cola-2
# 102. coca-cola-2023
# 103. coca-colaofficial
# 104. coca-colaoficial
# 105. cocacola_1
# 106. cocacol4
# 107. coca-cola-2024
# 108. cocacola-US
# 109. cocacola2
# 110. coca-cola_US
# 111. Cocacola
# 112. cocacola-4
# 113. coc4cola
# 114. c0ca-cola
# 115. cocacola_4
# 116. cocacola2023
# 117. cocacola2020
# 118. coca-cola_oficial
# 119. coca-cola_2024
# 120. cocacola_2025
# 121. cocacola america
# 122. cocacola_mexico
# 123. coca-cola4
# 124. coca-cola_mexico
# 125. coca-cola5
# 126. coc@-cola
# 127. cocacolapage
# 128. coca-cola-america
# 129. cocacola-oficial
# 130. cocacolaMX
# 131. coca-col@
# 132. coca-colaUS
# 133. cocacola_america
# 134. cocacola2021
# 135. cocacola page
# 136. COCACOLA
# 137. cocacola_2022
# 138. cocacola_official
# 139. cocacola1
# 140. cocacola_2021
# 141. coca-cola_2022
# 142. coca-cola2022
# 143. cocacola_5
# 144. cocacola_page
# 145. cocacola-page
#
# Plataformas a analizar: facebook, x, instagram
#
# URLs generadas para facebook:
# 1. https://www.facebook.com/coca-cola_2025
# 2. https://www.facebook.com/coca-cola-2021
# 3. https://www.facebook.com/cocacola-MX
# 4. https://www.facebook.com/coca-cola_2023
# 5. https://www.facebook.com/coca-cola page
# 6. https://www.facebook.com/Coca-cola
# 7. https://www.facebook.com/cocacola2024
# 8. https://www.facebook.com/coca-cola2024
# 9. https://www.facebook.com/cocacola_fan
# 10. https://www.facebook.com/coca-cola-page
# 11. https://www.facebook.com/cocacola-official
# 12. https://www.facebook.com/cocacola mexico
# 13. https://www.facebook.com/coca-cola-4
# 14. https://www.facebook.com/coca-cola_1
# 15. https://www.facebook.com/coca-colaamerica
# 16. https://www.facebook.com/coca-cola_america
# 17. https://www.facebook.com/cocacola-2024
# 18. https://www.facebook.com/cocacola official
# 19. https://www.facebook.com/cocacola
# 20. https://www.facebook.com/cocacola_MX
# 21. https://www.facebook.com/coca-colafan
# 22. https://www.facebook.com/coca-cola2020
# 23. https://www.facebook.com/coca-cola1
# 24. https://www.facebook.com/coc4-cola
# 25. https://www.facebook.com/cocacola-2020
# 26. https://www.facebook.com/cocacolaamerica
# 27. https://www.facebook.com/cocacola-mexico
# 28. https://www.facebook.com/cocacola-1
# 29. https://www.facebook.com/cocacolaUS
# 30. https://www.facebook.com/coca-cola-oficial
# 31. https://www.facebook.com/cocacola-2025
# 32. https://www.facebook.com/coca-cola fan
# 33. https://www.facebook.com/cocacol@
# 34. https://www.facebook.com/coca-cola-US
# 35. https://www.facebook.com/coca-cola2025
# 36. https://www.facebook.com/cocacola-2022
# 37. https://www.facebook.com/coca-c0la
# 38. https://www.facebook.com/coca-cola-2020
# 39. https://www.facebook.com/coca-cola-mexico
# 40. https://www.facebook.com/coca-cola_MX
# 41. https://www.facebook.com/cocacola_US
# 42. https://www.facebook.com/coca-cola_4
# 43. https://www.facebook.com/cocacola_2
# 44. https://www.facebook.com/coca-cola oficial
# 45. https://www.facebook.com/coca-cola_2020
# 46. https://www.facebook.com/coca-cola
# 47. https://www.facebook.com/cocacola-2021
# 48. https://www.facebook.com/cocacola2022
# 49. https://www.facebook.com/coca-cola-official
# 50. https://www.facebook.com/coca-colaMX
# 51. https://www.facebook.com/coca-colamexico
# 52. https://www.facebook.com/cocacola-2
# 53. https://www.facebook.com/coca-cola_2021
# 54. https://www.facebook.com/coc@cola
# 55. https://www.facebook.com/cocacola5
# 56. https://www.facebook.com/cocacola4
# 57. https://www.facebook.com/coca-cola-2025
# 58. https://www.facebook.com/coca-cola_fan
# 59. https://www.facebook.com/cocacola-2023
# 60. https://www.facebook.com/coca-cola-1
# 61. https://www.facebook.com/cocacola_2024
# 62. https://www.facebook.com/cocacola_2023
# 63. https://www.facebook.com/cocacola_oficial
# 64. https://www.facebook.com/coca-colapage
# 65. https://www.facebook.com/cocacola2025
# 66. https://www.facebook.com/coca-cola_5
# 67. https://www.facebook.com/coca-cola2023
# 68. https://www.facebook.com/cocacola_2020
# 69. https://www.facebook.com/cocacola-fan
# 70. https://www.facebook.com/coca-cola-MX
# 71. https://www.facebook.com/coca-cola-2022
# 72. https://www.facebook.com/coca-cola-fan
# 73. https://www.facebook.com/cocacolafan
# 74. https://www.facebook.com/coca-cola_2
# 75. https://www.facebook.com/coca-col4
# 76. https://www.facebook.com/cocacola fan
# 77. https://www.facebook.com/cocacola-3
# 78. https://www.facebook.com/cocacola-5
# 79. https://www.facebook.com/COCA-COLA
# 80. https://www.facebook.com/coca-cola_official
# 81. https://www.facebook.com/cocacola-america
# 82. https://www.facebook.com/cocacola3
# 83. https://www.facebook.com/coca-cola mexico
# 84. https://www.facebook.com/coca-cola official
# 85. https://www.facebook.com/cocacolamexico
# 86. https://www.facebook.com/cocacola oficial
# 87. https://www.facebook.com/cocacolaoficial
# 88. https://www.facebook.com/coca-cola_page
# 89. https://www.facebook.com/coca-cola america
# 90. https://www.facebook.com/coca-cola2021
# 91. https://www.facebook.com/coca-cola2
# 92. https://www.facebook.com/coca-cola_3
# 93. https://www.facebook.com/cocac0la
# 94. https://www.facebook.com/coca-cola-3
# 95. https://www.facebook.com/Coca-Cola
# 96. https://www.facebook.com/coca-cola-5
# 97. https://www.facebook.com/cocacola_3
# 98. https://www.facebook.com/c0cacola
# 99. https://www.facebook.com/cocacolaofficial
# 100. https://www.facebook.com/coca-cola3
# 101. https://www.facebook.com/coca-cola-2
# 102. https://www.facebook.com/coca-cola-2023
# 103. https://www.facebook.com/coca-colaofficial
# 104. https://www.facebook.com/coca-colaoficial
# 105. https://www.facebook.com/cocacola_1
# 106. https://www.facebook.com/cocacol4
# 107. https://www.facebook.com/coca-cola-2024
# 108. https://www.facebook.com/cocacola-US
# 109. https://www.facebook.com/cocacola2
# 110. https://www.facebook.com/coca-cola_US
# 111. https://www.facebook.com/Cocacola
# 112. https://www.facebook.com/cocacola-4
# 113. https://www.facebook.com/coc4cola
# 114. https://www.facebook.com/c0ca-cola
# 115. https://www.facebook.com/cocacola_4
# 116. https://www.facebook.com/cocacola2023
# 117. https://www.facebook.com/cocacola2020
# 118. https://www.facebook.com/coca-cola_oficial
# 119. https://www.facebook.com/coca-cola_2024
# 120. https://www.facebook.com/cocacola_2025
# 121. https://www.facebook.com/cocacola america
# 122. https://www.facebook.com/cocacola_mexico
# 123. https://www.facebook.com/coca-cola4
# 124. https://www.facebook.com/coca-cola_mexico
# 125. https://www.facebook.com/coca-cola5
# 126. https://www.facebook.com/coc@-cola
# 127. https://www.facebook.com/cocacolapage
# 128. https://www.facebook.com/coca-cola-america
# 129. https://www.facebook.com/cocacola-oficial
# 130. https://www.facebook.com/cocacolaMX
# 131. https://www.facebook.com/coca-col@
# 132. https://www.facebook.com/coca-colaUS
# 133. https://www.facebook.com/cocacola_america
# 134. https://www.facebook.com/cocacola2021
# 135. https://www.facebook.com/cocacola page
# 136. https://www.facebook.com/COCACOLA
# 137. https://www.facebook.com/cocacola_2022
# 138. https://www.facebook.com/cocacola_official
# 139. https://www.facebook.com/cocacola1
# 140. https://www.facebook.com/cocacola_2021
# 141. https://www.facebook.com/coca-cola_2022
# 142. https://www.facebook.com/coca-cola2022
# 143. https://www.facebook.com/cocacola_5
# 144. https://www.facebook.com/cocacola_page
# 145. https://www.facebook.com/cocacola-page
#
# URLs generadas para x:
# 1. https://x.com/coca-cola_2025
# 2. https://x.com/coca-cola-2021
# 3. https://x.com/cocacola-MX
# 4. https://x.com/coca-cola_2023
# 5. https://x.com/coca-cola page
# 6. https://x.com/Coca-cola
# 7. https://x.com/cocacola2024
# 8. https://x.com/coca-cola2024
# 9. https://x.com/cocacola_fan
# 10. https://x.com/coca-cola-page
# 11. https://x.com/cocacola-official
# 12. https://x.com/cocacola mexico
# 13. https://x.com/coca-cola-4
# 14. https://x.com/coca-cola_1
# 15. https://x.com/coca-colaamerica
# 16. https://x.com/coca-cola_america
# 17. https://x.com/cocacola-2024
# 18. https://x.com/cocacola official
# 19. https://x.com/cocacola
# 20. https://x.com/cocacola_MX
# 21. https://x.com/coca-colafan
# 22. https://x.com/coca-cola2020
# 23. https://x.com/coca-cola1
# 24. https://x.com/coc4-cola
# 25. https://x.com/cocacola-2020
# 26. https://x.com/cocacolaamerica
# 27. https://x.com/cocacola-mexico
# 28. https://x.com/cocacola-1
# 29. https://x.com/cocacolaUS
# 30. https://x.com/coca-cola-oficial
# 31. https://x.com/cocacola-2025
# 32. https://x.com/coca-cola fan
# 33. https://x.com/cocacol@
# 34. https://x.com/coca-cola-US
# 35. https://x.com/coca-cola2025
# 36. https://x.com/cocacola-2022
# 37. https://x.com/coca-c0la
# 38. https://x.com/coca-cola-2020
# 39. https://x.com/coca-cola-mexico
# 40. https://x.com/coca-cola_MX
# 41. https://x.com/cocacola_US
# 42. https://x.com/coca-cola_4
# 43. https://x.com/cocacola_2
# 44. https://x.com/coca-cola oficial
# 45. https://x.com/coca-cola_2020
# 46. https://x.com/coca-cola
# 47. https://x.com/cocacola-2021
# 48. https://x.com/cocacola2022
# 49. https://x.com/coca-cola-official
# 50. https://x.com/coca-colaMX
# 51. https://x.com/coca-colamexico
# 52. https://x.com/cocacola-2
# 53. https://x.com/coca-cola_2021
# 54. https://x.com/coc@cola
# 55. https://x.com/cocacola5
# 56. https://x.com/cocacola4
# 57. https://x.com/coca-cola-2025
# 58. https://x.com/coca-cola_fan
# 59. https://x.com/cocacola-2023
# 60. https://x.com/coca-cola-1
# 61. https://x.com/cocacola_2024
# 62. https://x.com/cocacola_2023
# 63. https://x.com/cocacola_oficial
# 64. https://x.com/coca-colapage
# 65. https://x.com/cocacola2025
# 66. https://x.com/coca-cola_5
# 67. https://x.com/coca-cola2023
# 68. https://x.com/cocacola_2020
# 69. https://x.com/cocacola-fan
# 70. https://x.com/coca-cola-MX
# 71. https://x.com/coca-cola-2022
# 72. https://x.com/coca-cola-fan
# 73. https://x.com/cocacolafan
# 74. https://x.com/coca-cola_2
# 75. https://x.com/coca-col4
# 76. https://x.com/cocacola fan
# 77. https://x.com/cocacola-3
# 78. https://x.com/cocacola-5
# 79. https://x.com/COCA-COLA
# 80. https://x.com/coca-cola_official
# 81. https://x.com/cocacola-america
# 82. https://x.com/cocacola3
# 83. https://x.com/coca-cola mexico
# 84. https://x.com/coca-cola official
# 85. https://x.com/cocacolamexico
# 86. https://x.com/cocacola oficial
# 87. https://x.com/cocacolaoficial
# 88. https://x.com/coca-cola_page
# 89. https://x.com/coca-cola america
# 90. https://x.com/coca-cola2021
# 91. https://x.com/coca-cola2
# 92. https://x.com/coca-cola_3
# 93. https://x.com/cocac0la
# 94. https://x.com/coca-cola-3
# 95. https://x.com/Coca-Cola
# 96. https://x.com/coca-cola-5
# 97. https://x.com/cocacola_3
# 98. https://x.com/c0cacola
# 99. https://x.com/cocacolaofficial
# 100. https://x.com/coca-cola3
# 101. https://x.com/coca-cola-2
# 102. https://x.com/coca-cola-2023
# 103. https://x.com/coca-colaofficial
# 104. https://x.com/coca-colaoficial
# 105. https://x.com/cocacola_1
# 106. https://x.com/cocacol4
# 107. https://x.com/coca-cola-2024
# 108. https://x.com/cocacola-US
# 109. https://x.com/cocacola2
# 110. https://x.com/coca-cola_US
# 111. https://x.com/Cocacola
# 112. https://x.com/cocacola-4
# 113. https://x.com/coc4cola
# 114. https://x.com/c0ca-cola
# 115. https://x.com/cocacola_4
# 116. https://x.com/cocacola2023
# 117. https://x.com/cocacola2020
# 118. https://x.com/coca-cola_oficial
# 119. https://x.com/coca-cola_2024
# 120. https://x.com/cocacola_2025
# 121. https://x.com/cocacola america
# 122. https://x.com/cocacola_mexico
# 123. https://x.com/coca-cola4
# 124. https://x.com/coca-cola_mexico
# 125. https://x.com/coca-cola5
# 126. https://x.com/coc@-cola
# 127. https://x.com/cocacolapage
# 128. https://x.com/coca-cola-america
# 129. https://x.com/cocacola-oficial
# 130. https://x.com/cocacolaMX
# 131. https://x.com/coca-col@
# 132. https://x.com/coca-colaUS
# 133. https://x.com/cocacola_america
# 134. https://x.com/cocacola2021
# 135. https://x.com/cocacola page
# 136. https://x.com/COCACOLA
# 137. https://x.com/cocacola_2022
# 138. https://x.com/cocacola_official
# 139. https://x.com/cocacola1
# 140. https://x.com/cocacola_2021
# 141. https://x.com/coca-cola_2022
# 142. https://x.com/coca-cola2022
# 143. https://x.com/cocacola_5
# 144. https://x.com/cocacola_page
# 145. https://x.com/cocacola-page
#
# URLs generadas para instagram:
# 1. https://www.instagram.com/coca-cola_2025
# 2. https://www.instagram.com/coca-cola-2021
# 3. https://www.instagram.com/cocacola-MX
# 4. https://www.instagram.com/coca-cola_2023
# 5. https://www.instagram.com/coca-cola page
# 6. https://www.instagram.com/Coca-cola
# 7. https://www.instagram.com/cocacola2024
# 8. https://www.instagram.com/coca-cola2024
# 9. https://www.instagram.com/cocacola_fan
# 10. https://www.instagram.com/coca-cola-page
# 11. https://www.instagram.com/cocacola-official
# 12. https://www.instagram.com/cocacola mexico
# 13. https://www.instagram.com/coca-cola-4
# 14. https://www.instagram.com/coca-cola_1
# 15. https://www.instagram.com/coca-colaamerica
# 16. https://www.instagram.com/coca-cola_america
# 17. https://www.instagram.com/cocacola-2024
# 18. https://www.instagram.com/cocacola official
# 19. https://www.instagram.com/cocacola
# 20. https://www.instagram.com/cocacola_MX
# 21. https://www.instagram.com/coca-colafan
# 22. https://www.instagram.com/coca-cola2020
# 23. https://www.instagram.com/coca-cola1
# 24. https://www.instagram.com/coc4-cola
# 25. https://www.instagram.com/cocacola-2020
# 26. https://www.instagram.com/cocacolaamerica
# 27. https://www.instagram.com/cocacola-mexico
# 28. https://www.instagram.com/cocacola-1
# 29. https://www.instagram.com/cocacolaUS
# 30. https://www.instagram.com/coca-cola-oficial
# 31. https://www.instagram.com/cocacola-2025
# 32. https://www.instagram.com/coca-cola fan
# 33. https://www.instagram.com/cocacol@
# 34. https://www.instagram.com/coca-cola-US
# 35. https://www.instagram.com/coca-cola2025
# 36. https://www.instagram.com/cocacola-2022
# 37. https://www.instagram.com/coca-c0la
# 38. https://www.instagram.com/coca-cola-2020
# 39. https://www.instagram.com/coca-cola-mexico
# 40. https://www.instagram.com/coca-cola_MX
# 41. https://www.instagram.com/cocacola_US
# 42. https://www.instagram.com/coca-cola_4
# 43. https://www.instagram.com/cocacola_2
# 44. https://www.instagram.com/coca-cola oficial
# 45. https://www.instagram.com/coca-cola_2020
# 46. https://www.instagram.com/coca-cola
# 47. https://www.instagram.com/cocacola-2021
# 48. https://www.instagram.com/cocacola2022
# 49. https://www.instagram.com/coca-cola-official
# 50. https://www.instagram.com/coca-colaMX
# 51. https://www.instagram.com/coca-colamexico
# 52. https://www.instagram.com/cocacola-2
# 53. https://www.instagram.com/coca-cola_2021
# 54. https://www.instagram.com/coc@cola
# 55. https://www.instagram.com/cocacola5
# 56. https://www.instagram.com/cocacola4
# 57. https://www.instagram.com/coca-cola-2025
# 58. https://www.instagram.com/coca-cola_fan
# 59. https://www.instagram.com/cocacola-2023
# 60. https://www.instagram.com/coca-cola-1
# 61. https://www.instagram.com/cocacola_2024
# 62. https://www.instagram.com/cocacola_2023
# 63. https://www.instagram.com/cocacola_oficial
# 64. https://www.instagram.com/coca-colapage
# 65. https://www.instagram.com/cocacola2025
# 66. https://www.instagram.com/coca-cola_5
# 67. https://www.instagram.com/coca-cola2023
# 68. https://www.instagram.com/cocacola_2020
# 69. https://www.instagram.com/cocacola-fan
# 70. https://www.instagram.com/coca-cola-MX
# 71. https://www.instagram.com/coca-cola-2022
# 72. https://www.instagram.com/coca-cola-fan
# 73. https://www.instagram.com/cocacolafan
# 74. https://www.instagram.com/coca-cola_2
# 75. https://www.instagram.com/coca-col4
# 76. https://www.instagram.com/cocacola fan
# 77. https://www.instagram.com/cocacola-3
# 78. https://www.instagram.com/cocacola-5
# 79. https://www.instagram.com/COCA-COLA
# 80. https://www.instagram.com/coca-cola_official
# 81. https://www.instagram.com/cocacola-america
# 82. https://www.instagram.com/cocacola3
# 83. https://www.instagram.com/coca-cola mexico
# 84. https://www.instagram.com/coca-cola official
# 85. https://www.instagram.com/cocacolamexico
# 86. https://www.instagram.com/cocacola oficial
# 87. https://www.instagram.com/cocacolaoficial
# 88. https://www.instagram.com/coca-cola_page
# 89. https://www.instagram.com/coca-cola america
# 90. https://www.instagram.com/coca-cola2021
# 91. https://www.instagram.com/coca-cola2
# 92. https://www.instagram.com/coca-cola_3
# 93. https://www.instagram.com/cocac0la
# 94. https://www.instagram.com/coca-cola-3
# 95. https://www.instagram.com/Coca-Cola
# 96. https://www.instagram.com/coca-cola-5
# 97. https://www.instagram.com/cocacola_3
# 98. https://www.instagram.com/c0cacola
# 99. https://www.instagram.com/cocacolaofficial
# 100. https://www.instagram.com/coca-cola3
# 101. https://www.instagram.com/coca-cola-2
# 102. https://www.instagram.com/coca-cola-2023
# 103. https://www.instagram.com/coca-colaofficial
# 104. https://www.instagram.com/coca-colaoficial
# 105. https://www.instagram.com/cocacola_1
# 106. https://www.instagram.com/cocacol4
# 107. https://www.instagram.com/coca-cola-2024
# 108. https://www.instagram.com/cocacola-US
# 109. https://www.instagram.com/cocacola2
# 110. https://www.instagram.com/coca-cola_US
# 111. https://www.instagram.com/Cocacola
# 112. https://www.instagram.com/cocacola-4
# 113. https://www.instagram.com/coc4cola
# 114. https://www.instagram.com/c0ca-cola
# 115. https://www.instagram.com/cocacola_4
# 116. https://www.instagram.com/cocacola2023
# 117. https://www.instagram.com/cocacola2020
# 118. https://www.instagram.com/coca-cola_oficial
# 119. https://www.instagram.com/coca-cola_2024
# 120. https://www.instagram.com/cocacola_2025
# 121. https://www.instagram.com/cocacola america
# 122. https://www.instagram.com/cocacola_mexico
# 123. https://www.instagram.com/coca-cola4
# 124. https://www.instagram.com/coca-cola_mexico
# 125. https://www.instagram.com/coca-cola5
# 126. https://www.instagram.com/coc@-cola
# 127. https://www.instagram.com/cocacolapage
# 128. https://www.instagram.com/coca-cola-america
# 129. https://www.instagram.com/cocacola-oficial
# 130. https://www.instagram.com/cocacolaMX
# 131. https://www.instagram.com/coca-col@
# 132. https://www.instagram.com/coca-colaUS
# 133. https://www.instagram.com/cocacola_america
# 134. https://www.instagram.com/cocacola2021
# 135. https://www.instagram.com/cocacola page
# 136. https://www.instagram.com/COCACOLA
# 137. https://www.instagram.com/cocacola_2022
# 138. https://www.instagram.com/cocacola_official
# 139. https://www.instagram.com/cocacola1
# 140. https://www.instagram.com/cocacola_2021
# 141. https://www.instagram.com/coca-cola_2022
# 142. https://www.instagram.com/coca-cola2022
# 143. https://www.instagram.com/cocacola_5
# 144. https://www.instagram.com/cocacola_page
# 145. https://www.instagram.com/cocacola-page
